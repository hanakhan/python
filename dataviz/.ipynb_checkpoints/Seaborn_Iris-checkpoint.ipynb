# %% [markdown]
# # Visualizing the Iris Data
#
# Description of this dataset taken from https://www.kaggle.com/uciml/iris:
# The Iris dataset was used in Fisher's classic 1936 paper, The Use of Multiple Measurements in Taxonomic Problems.
#
# It includes three iris species with 50 samples each as well as some properties about each flower. One flower species is linearly separable from the other two, but the other two are not linearly separable from each other.
#
# The columns in this dataset are:
#
# Id,
# SepalLengthCm,
# SepalWidthCm,
# PetalLengthCm,
# PetalWidthCm,
# Species

# %%
#Import libraries
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Import dataset
iris = sns.load_dataset('iris')

# %%
#View the data
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## PairGrid
#
# Pairgrid is a subplot grid for plotting pairwise relationships in a dataset.

# %%
# Create emptry grids to plot the data into later
g = sns.PairGrid(iris)
# Then map scatter plots to the grid
g.map(plt.scatter)

# %% [markdown]
# These plots show some clustering that is likely a result of different iris species present in the data. Neverthless, a positive relationship can be seen between petal_length and petal_width, as well as between petal_length and sepal_length for one or two of the clusters.

# %%
# We can adjust the pairgrid to plot other types of plots and avoid redundancy
# Map to upper,lower, and diagonal
g = sns.PairGrid(iris)
g.map_diag(plt.hist)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)

# %% [markdown]
# Plotting the histogram across the diagonal cells is a common practice since those cells would otherwise contain correlations between the same variable. The kde plots show some separation between clusters that we could see in the scatter plots.

# %% [markdown]
# pairplot is a simpler version of PairGrid that will map histograms across the diagonal grids as a default

# %%
# Let's create a pairplot with the hue set to 'species' column so we can distinguish the patterns between species
sns.pairplot(iris,hue='species',palette='Set2')

# %% [markdown]
# The setosa species has a much clearer separation from the other species in many of these plots.

# %% [markdown]
# ## JointGrid
#
# JointGrid is the general version for jointplot() type grids, for a quick example:

# %%
g = sns.JointGrid(x="petal_length", y="sepal_length", data=iris)
g = g.plot(sns.regplot, sns.distplot)

# %% [markdown]
# This jointgrid between petal_length and sepal_width shows a scatter plot with a regression line between the two variables. In the margins of jointgrids, univariate information can be plotted for that corresponding variable. We can see two humps in the petal_length histogram. The previous pairplots showed the setosa species having a shorter petal length than the other two species, which is shown by these two humps. In the scatter plot, we can also see the cluster for the setosa species showing a different scatter pattern than the other two species. In fact, the setosa species is reducing the correlation between petal length and sepal length. The next plot will re-map these variables but without the setosa data.

# %%
# Re-plotting by excluding the setosa species
g = sns.JointGrid(x="petal_length", y="sepal_length", data=iris[iris['species']!='setosa'])
g = g.plot(sns.regplot, sns.distplot)
